# %% [markdown]
# Tasks to be performed:
# 1. Building the k-means clustering algorithm:
# a. Start off by extracting the ‘mpg’, ‘disp’ & ‘hp’ columns from the ‘mtcars’ data.frame.
# Store the result in ‘car_features’

# %%
# Import required libraries

import pandas as pd
from sklearn.cluster import KMeans

# %%
# Load the cars-1 dataset

cars = pd.read_csv('cars-1.csv')

# %%
# Extract the required columns

car_features = cars[['mpg', 'disp', 'hp']]

# %% [markdown]
# b. Build the kmeans algorithm on top of ‘car_features’. Here, the number of clusters should be 3

# %%
kmeans_model_5 = KMeans(n_clusters = 3, random_state = 123).fit(car_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %% [markdown]
# c. Bind the clustering vector to ‘car_features’.

# %%
# Bind the clustering vector to car_features
car_features['cluster'] = kmeans_model_5.labels_
# Out:
# <ipython-input-8-5d5e74080e98>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_features['cluster'] = kmeans_model_5.labels_

# %% [markdown]
# d. Extract observations belonging to individual clusters

# %%
# Extract observations belonging to each cluster
cluster_1 = car_features[car_features['cluster'] == 0]
cluster_2 = car_features[car_features['cluster'] == 1]
cluster_3 = car_features[car_features['cluster'] == 2]
cluster_4 = car_features[car_features['cluster'] == 3]
cluster_5 = car_features[car_features['cluster'] == 4]

# %% [markdown]
# On the same ‘car_features’dataset build a k-means algorithm, where the number of clusters is 5
#
# a. Bind the clustering vector to ‘car_features’
#
# b. Extract observations belonging to individual clusters

# %%
# Build the k-means algorithm with 5 clusters
kmeans_model_5 = KMeans(n_clusters=5, random_state=123).fit(car_features)

# Bind the clustering vector to car_features
car_features['cluster'] = kmeans_model_5.labels_

# Extract observations belonging to each cluster
cluster_1 = car_features[car_features['cluster'] == 0]
cluster_2 = car_features[car_features['cluster'] == 1]
cluster_3 = car_features[car_features['cluster'] == 2]
cluster_4 = car_features[car_features['cluster'] == 3]
cluster_5 = car_features[car_features['cluster'] == 4]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-11-f7358c0c138b>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_features['cluster'] = kmeans_model_5.labels_

# %% [markdown]
# # KMeans Clustering Assignment

# %% [markdown]
# Tasks to be performed:
# 1. K-Means Clustering:
# - Load customer data.
# - Check the number of cells in each column with null values.
# - Create a scatter plot with Age as X and Spending Score as Y.
# - Draw a scatter plot displaying data points colored on the basis of clusters.

# %%
# Import required libraries
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
# Load the dataset
customers = pd.read_csv('customers.csv')

# Check the first 5 rows of the dataset
customers.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# Check for null values
print(customers.isnull().sum())
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# Create a scatter plot of Age vs Spending Score
plt.scatter(customers['Age'], customers['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.show()

# %%
# Extract the required columns
customer_features = customers[['Age', 'Spending Score (1-100)']]

# Build the k-means algorithm with 5 clusters
kmeans_model = KMeans(n_clusters=5, random_state=123).fit(customer_features)

# Bind the clustering vector to customer_features
customer_features['cluster'] = kmeans_model.labels_

# Create a scatter plot with colored clusters
plt.scatter(customer_features['Age'], customer_features['Spending Score (1-100)'], c=customer_features['cluster'], cmap='viridis')
plt.xlabel('Age')
plt.ylabel('Spending Score')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# <ipython-input-19-3039eb41d5c7>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_features['cluster'] = kmeans_model.labels_

# %% [markdown]
# # KMeans Clustering Assignment

# %% [markdown]
# Tasks to be performed:
# 1. K-Means Clustering:
# - Load customer data.
# - Check the number of cells in each column with null values.
# - Create a scatter plot with Age as X and Spending Score as Y.
# - Find out the best number for clusters between 1 and 10 (inclusive) using the elbowmethod.
# - Draw a scatter plot displaying data points colored on the basis of clusters.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# load customer data
customers = pd.read_csv('customers.csv')

# Check the first 5 rows of the dataset
customers.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
# check for null values in each column

print(customers.isnull().sum())
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
# create scatter plot with Age as X and Spending Score as Y

plt.scatter(x=customers['Age'], y=customers['Spending Score (1-100)'])
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.show()

# %%
# One-hot encode the "Gender" column
customers = pd.get_dummies(customers, columns=['Gender'], prefix='', prefix_sep='')

# %%
# find the best number of clusters using the elbow method

wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(customers.iloc[:, 1:])
    wcss.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
# Plot the elbow curve

plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of Clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# Fit KMeans with the best number of clusters
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
kmeans.fit(customers.iloc[:, 1:])
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=5, random_state=42)

# %%
# Scatter plot with data points colored by cluster
plt.scatter(customers['Age'], customers['Spending Score (1-100)'], c=kmeans.labels_)
plt.xlabel('Age')
plt.ylabel('Spending Score (1-100)')
plt.show()

# %% [markdown]
# #  Agglomerative Clustering Assignment

# %% [markdown]
# Tasks to be performed:
# - Load iris data from load_iris function from sklearn.datasets package.
# - From the dataset extract the data properly.
# - Train an AgglomerativeClustring model based on the data.
# - Plot dendrogram to visualize the clustering linkage

# %%
from sklearn.datasets import load_iris
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# Load the iris dataset
iris = load_iris()

# %%
# Extract the features from the dataset
X = iris.data

# %%
# Train the agglomerative clustering model
Z = linkage(X, method='ward')

# %%
# Plot the dendrogram
plt.figure(figsize=(12, 8))
plt.title('Hierarchical Clustering Dendrogram')
plt.xlabel('Index')
plt.ylabel('Distance')
dendrogram(Z, leaf_rotation=90., leaf_font_size=8.)
plt.show()

# %% [markdown]
# # Dendrogram Assignment

# %% [markdown]
# Data:[[5,3],
#
# [10,15],
#
# [15,12],
#
# [24,10],
#
# [30,30],
#
# [85,70],
#
# [71,80],
#
# [60,78],
#
# [70,55],
#
# [80,91],]
#
# Tasks to be performed:
#
#  Using the np.array function create an np array from the data given above.
#
#  Generate a scatter plot for the data.
#
#  Plot dendrogram to visualize the clustering linkage

# %%
import numpy as np
from scipy.cluster.hierarchy import dendrogram, linkage
import matplotlib.pyplot as plt

# Creating numpy array from given data
data = np.array([[5,3],
                [10,15],
                [15,12],
                [24,10],
                [30,30],
                [85,70],
                [71,80],
                [60,78],
                [70,55],
                [80,91]])

# %%
# Plotting scatter plot for the data
plt.scatter(data[:,0], data[:,1])

# %%
# Generating linkage matrix using ward method
link_matrix = linkage(data, 'ward')

# %%
# Plotting dendrogram to visualize clustering linkage
plt.figure(figsize=(10, 7))
dendrogram(link_matrix)
plt.show()
